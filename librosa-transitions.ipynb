# %%
import librosa
import librosa.display

# %%
filename = "data/sample_avaion.mp3"

# %%
filename
# Out:
# 'data/sample_avaion.mp3'

# %%
y, sr = librosa.load(filename)
# Out:
# C:\Users\Garsd\anaconda3\envs\env_tracklist\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)

# %%
librosa.display.waveshow(y)
